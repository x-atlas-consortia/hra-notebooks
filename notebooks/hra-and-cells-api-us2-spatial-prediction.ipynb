# %% [markdown]
# # Using the HuBMAP Cells API and the HRA API for Spatial Prediction

# %% [markdown]
# Find all HuBMAP datasets with Cell Ontology annotated cells via Azimuth with the Cells API, then use the cell populations for each dataset to find relevant datasets, rui locations, and anatomical structures using the Human Reference Atlas HRApop features in the HRA API. Visualize the results via HRA Jupyter Widgets, including a custom EUI.

# %% [markdown]
# # Install libraries

# %%
# !pip install --upgrade hra_api_client hubmap_api_py_client hra_jupyter_widgets
# Out:
# Requirement already satisfied: hra_api_client in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: hubmap_api_py_client in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (0.0.11)
# Requirement already satisfied: hra_jupyter_widgets in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: urllib3<2.1.0,>=1.25.3 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_api_client) (2.0.7)
# Requirement already satisfied: typing-extensions>=4.7.1 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_api_client) (4.12.2)
# Requirement already satisfied: python-dateutil in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_api_client) (2.9.0.post0)
# Requirement already satisfied: pydantic>=2 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_api_client) (2.9.2)
# Requirement already satisfied: requests>=2.0.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hubmap_api_py_client) (2.32.3)
# Requirement already satisfied: traitlets>=5.10 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_jupyter_widgets) (5.14.3)
# Requirement already satisfied: anywidget in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from hra_jupyter_widgets) (0.9.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from pydantic>=2->hra_api_client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from pydantic>=2->hra_api_client) (2.23.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from requests>=2.0.0->hubmap_api_py_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from requests>=2.0.0->hubmap_api_py_client) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from requests>=2.0.0->hubmap_api_py_client) (3.3.2)
# Requirement already satisfied: ipywidgets>=7.6.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from anywidget->hra_jupyter_widgets) (8.1.5)
# Requirement already satisfied: psygnal>=0.8.1 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from anywidget->hra_jupyter_widgets) (0.11.1)
# Requirement already satisfied: six>=1.5 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from python-dateutil->hra_api_client) (1.16.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (3.0.13)
# Requirement already satisfied: ipython>=6.1.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (8.27.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (4.0.13)
# Requirement already satisfied: comm>=0.1.3 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.2.2)
# Requirement already satisfied: matplotlib-inline in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (3.0.47)
# Requirement already satisfied: pexpect>4.3 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.19.1)
# Requirement already satisfied: decorator in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/bherr/workspaces/hubmap/hra-notebooks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget->hra_jupyter_widgets) (2.1.0)

# %% [markdown]
# # Part 1: Get Cell Populations from HuBMAP Datasets using the Cells API

# %% [markdown]
# Imports / functions

# %%
from hubmap_api_py_client import Client
from collections import Counter

# %% [markdown]
# Setup the HuBMAP Cells API Client

# %%
endpoint_url = "https://cells.api.hubmapconsortium.org/api/"
client = Client(endpoint_url)

# %% [markdown]
# Find cell types that have annotated datasets

# %%
all_celltypes = client.select_celltypes()
assert len(all_celltypes) > 0

celltypes = [c["grouping_name"] for c in all_celltypes.get_list()]
print('cell types:', len(celltypes))
# Out:
# cell types: 63

# %% [markdown]
# Find all datasets that have been annotated with cell types

# %%
datasets = client.select_datasets(where='celltype', has=celltypes).get_list()
assert len(datasets) > 0

uuids = [ d['uuid'] for d in datasets ]
print('annotated datasets with cell types:', len(datasets))
# Out:
# annotated datasets with cell types: 45

# %% [markdown]
# Get cells for each annotated dataset

# %%
dataset_cells = {}
dataset_organ = {}
dataset_modality = {}

for uuid in uuids:
    cells_in_dataset = client.select_cells(where='dataset', has=[uuid])
    all_cells = cells_in_dataset.get_list().results_set.get_list()

    population = Counter()
    for cell in all_cells:
        population[cell['cell_type']] += 1
        dataset_organ[uuid] = cell['organ'].lower()
        dataset_modality[uuid] = cell['modality']

    dataset_cells[uuid] = population

# %% [markdown]
# Show raw data results for one dataset

# %%
print(uuids[0], 'top cell types:', dataset_cells[uuids[0]].most_common(5))
print(uuids[0], 'organ:', dataset_organ[uuids[0]])
print(uuids[0], 'modality:', dataset_modality[uuids[0]])
# Out:
# 007f3dfaaa287d5c7c227651f61a9c5b top cell types: [('CL:0000057', 1868), ('CL:0000235', 621), ('CL:0002131', 532), ('CL:0002144', 310), ('CL:0000763', 273)]
# 007f3dfaaa287d5c7c227651f61a9c5b organ: heart
# 007f3dfaaa287d5c7c227651f61a9c5b modality: rna

# %% [markdown]
# # Part 2: Predict Spatial Locations Using the HRA API

# %% [markdown]
# Imports / functions

# %%
import hra_api_client
import time
import json
from hra_api_client.api import v1_api, hra_pop_api

# %% [markdown]
# Setup the HRA API Client

# %%
hra_api_endpoint_url = "https://apps.humanatlas.io/api"
configuration = hra_api_client.Configuration(hra_api_endpoint_url)
api_client = hra_api_client.ApiClient(configuration)
hra_api = v1_api.V1Api(api_client)
hra_pop_api = hra_pop_api.HraPopApi(api_client)

# %% [markdown]
# Get supported organ lookup

# %%
organ_lookup = dict((organ.label.lower(), organ.id) for organ in hra_pop_api.supported_organs())
organ_lookup
# Out:
# {'small intestine': 'http://purl.obolibrary.org/obo/UBERON_0002108',
#  'heart': 'http://purl.obolibrary.org/obo/UBERON_0000948',
#  'kidney': 'http://purl.obolibrary.org/obo/UBERON_0002113',
#  'large intestine': 'http://purl.obolibrary.org/obo/UBERON_0000059',
#  'liver': 'http://purl.obolibrary.org/obo/UBERON_0002107',
#  'lung': 'http://purl.obolibrary.org/obo/UBERON_0002048',
#  'skin': 'http://purl.obolibrary.org/obo/UBERON_0002097',
#  'skin of body': 'http://purl.obolibrary.org/obo/UBERON_0002097',
#  'spleen': 'http://purl.obolibrary.org/obo/UBERON_0002106',
#  'ureter': 'http://purl.obolibrary.org/obo/UBERON_0000056',
#  'urinary bladder': 'http://purl.obolibrary.org/obo/UBERON_0001255'}

# %% [markdown]
# Get HRApop cell summary reports for each dataset

# %%
dataset_summary = {}

from ipywidgets import IntProgress
progress = IntProgress(min=0, max=len(uuids))
display(progress)

for uuid in uuids:
    progress.value += 1
    total_count = sum(dataset_cells[uuid].values())
    csv = "\n".join(["cell_id,percentage"] + [ f"{cell_id},{count / total_count}" for (cell_id,count) in dataset_cells[uuid].items() ])
    dataset_summary[uuid] = json.loads(hra_pop_api.cell_summary_report_without_preload_content({ "csvString": csv }).data)
# Out:
# IntProgress(value=0, max=45)

# %% [markdown]
# Show raw data results for one dataset

# %%
print(uuids[0], 'has similar sources:', len(dataset_summary[uuids[0]]['sources']))
print(uuids[0], 'has similar RUI locations:', len(dataset_summary[uuids[0]]['rui_locations']))

dataset_summary[uuids[0]]['rui_locations']
# Out:
# 007f3dfaaa287d5c7c227651f61a9c5b has similar sources: 445
# 007f3dfaaa287d5c7c227651f61a9c5b has similar RUI locations: 2
# {'@context': 'https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld',
#  '@graph': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '3',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male, Age 3'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '3',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male, Age 3'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#      'placement': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#       'target': 'ccf:latest/ccf.owl#VHFLungV1.1',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '68.135'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '104.402'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '84.071'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '31',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male, Age 31'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#      'placement': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#       'target': 'ccf:latest/ccf.owl#VHFLungV1.1',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '68.135'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '104.402'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '84.071'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '3',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Female',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Female, Age 3'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D175$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D062$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D032$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D122$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D150$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D046$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#      'placement': {'@id': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/da60f474-614a-4e0a-adbe-521ba44c7bf0',
#       'target': 'ccf:latest/ccf.owl#VHMLung',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '49.919'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '101.788'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '110.357'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7363',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '29',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Male',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Male, Age 29'},
#   {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231_Donor',
#    'samples': {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231_Donor_TissueBlock1',
#     '@type': 'Sample',
#     'donor': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231_Donor',
#     'datasets': [{'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D231$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D088$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#      {'@id': 'https://api.cellxgene.cziscience.com/dp/v1/collections/625f6bf4-2f33-4942-962e-35243d284837#D139$lung',
#       '@type': 'Dataset',
#       'technology': 'OTHER',
#       'thumbnail': 'assets/logo.jpg',
#       'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#       'description': 'Data/Assay Types: OTHER, ',
#       'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'}],
#     'rui_location': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#      'placement': {'@id': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/6acd66b8-2659-4626-bef9-a80f135489ad',
#       'target': 'ccf:latest/ccf.owl#VHFLungV1.1',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-101'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '68.135'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '134'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '104.402'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '77'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '84.071'},
#       'creation_date': '2023-04-25'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002048',
#       '../sig/ont/fma/fma7360',
#       '../sig/ont/fma/fma7361',
#       '../sig/ont/fma/fma7401'],
#      'creator_first_name': 'Allen',
#      'creator_last_name': 'Wang',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'creation_date': '2023-04-25',
#      'creator': 'Allen Wang'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#     'description': '5 x 5 x 3 millimeter, 3 millimeter',
#     'label': 'Registered 3/24/2023, Allen Wang, NHLBI/LungMap'},
#    '@type': 'Donor',
#    'age': '33',
#    'consortium_name': 'NHLBI/LungMap',
#    'sex': 'Female',
#    'provider_name': 'NHLBI/LungMap',
#    'provider_uuid': '0ec3cf4a-4a28-496a-b66e-df34f4cd32e1',
#    'link': 'https://data-browser.lungmap.net/explore/projects/20037472-ea1d-4ddb-9cd3-56a11a6f0f76',
#    'description': 'Entered 3/24/2023, Allen Wang, NHLBI/LungMap',
#    'label': 'Female, Age 33'},
# ...
#         '@value': '1'},
#        'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '54.602'},
#        'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-25'},
#        'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '69.821'},
#        'creation_date': '2023-06-29'},
#       '@type': 'SpatialEntity',
#       'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002080',
#        'http://purl.obolibrary.org/obo/UBERON_0002084',
#        'http://purl.obolibrary.org/obo/UBERON_0002094',
#        'http://purl.obolibrary.org/obo/UBERON_0002494',
#        '../sig/ont/fma/fma72655'],
#       'creator_first_name': 'Andreas',
#       'creator_last_name': 'Bueckle',
#       'dimension_units': 'millimeter',
#       'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '10'},
#       'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '16'},
#       'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '10'},
#       'creation_date': '2023-06-29',
#       'creator': 'Andreas Bueckle'},
#      'sample_type': 'Tissue Block',
#      'sections': None,
#      'link': 'https://portal.hubmapconsortium.org/browse/sample/ec2ccf5a3436b11d0c7186b74ad4673d',
#      'description': '10 x 16 x 10 millimeter, 10 millimeter, 1 Sections',
#      'label': 'Registered 6/29/2023, Yiing Lin, TMC-Stanford'}],
#    '@type': 'Donor',
#    'age': '37',
#    'bmi': '29.3',
#    'consortium_name': 'HuBMAP',
#    'sex': 'Male',
#    'provider_name': 'TMC-Stanford',
#    'provider_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'link': 'https://portal.hubmapconsortium.org/browse/donor/f84ff583687f3407636d8ce843b48ff0',
#    'description': 'Entered 3/21/2021, Yiing Lin, TMC-Stanford',
#    'label': 'Male, Age 37'},
#   {'@id': 'https://entity.api.hubmapconsortium.org/entities/f8d963cab6bd10e2a4b8184ea8197fc1',
#    'samples': [{'@id': 'https://entity.api.hubmapconsortium.org/entities/b2362226c142a855ddaa0fba0db29b95',
#      '@type': 'Sample',
#      'donor': 'https://entity.api.hubmapconsortium.org/entities/f8d963cab6bd10e2a4b8184ea8197fc1',
#      'datasets': [{'@id': 'https://entity.api.hubmapconsortium.org/entities/dd3e6da115fd13eee62d9a4fba2324ae',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/e010f7505632d7b6eeda25b349383149',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/615462a0e4aa133d8b19644c404e3eeb',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/704d16116f29994ab0e714f4afdb5516',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/739184f7ec84d93a35360cde81cc026c',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/a95f2c79bb637141f7e6874eddc8e274',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/c14b104f9e44511ddf82697bce0d1901',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/0804a7a9e430e6adfbc56f339d787211',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/2639e9e8488edddde275491cdbaae662',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/33c0ce043ae331ea23fc80023428e534',
#        '@type': 'Dataset'}],
#      'rui_location': {'@id': 'ccf:1.5/f66f91f9-c6c5-414d-b784-2faec33e0505',
#       'placement': {'@id': 'ccf:1.5/f66f91f9-c6c5-414d-b784-2faec33e0505_placement',
#        '@type': 'SpatialPlacement',
#        'source': 'ccf:1.5/f66f91f9-c6c5-414d-b784-2faec33e0505',
#        'target': 'ccf:latest/ccf.owl#VHFRightKidney',
#        'rotation_order': 'XYZ',
#        'rotation_units': 'degree',
#        'scaling_units': 'ratio',
#        'translation_units': 'millimeter',
#        'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-46'},
#        'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '53.213'},
#        'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-32'},
#        'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '74.416'},
#        'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-91'},
#        'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '20.489'},
#        'creation_date': '2021-10-03'},
#       '@type': 'SpatialEntity',
#       'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002189',
#        'http://purl.obolibrary.org/obo/UBERON_0004200',
#        'http://purl.obolibrary.org/obo/UBERON_0001228',
#        'http://purl.obolibrary.org/obo/UBERON_0002015',
#        'http://purl.obolibrary.org/obo/UBERON_0001227',
#        'http://purl.obolibrary.org/obo/UBERON_0006517',
#        'http://purl.obolibrary.org/obo/UBERON_0000362',
#        'http://purl.obolibrary.org/obo/UBERON_0001225',
#        'http://purl.obolibrary.org/obo/UBERON_0008716',
#        'http://purl.obolibrary.org/obo/UBERON_0001284'],
#       'creator_first_name': 'amanda',
#       'creator_last_name': 'knoten',
#       'dimension_units': 'millimeter',
#       'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '5'},
#       'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '12'},
#       'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '2'},
#       'creation_date': '2021-10-03',
#       'creator': 'amanda knoten'},
#      'sample_type': 'Tissue Block',
#      'sections': None,
#      'link': 'https://portal.hubmapconsortium.org/browse/sample/b2362226c142a855ddaa0fba0db29b95',
#      'description': '5 x 12 x 2 millimeter, 0.7 millimeter, 3 Sections',
#      'label': 'Registered 10/3/2021, Diane Salamon, TMC-UCSD'},
#     {'@id': 'https://entity.api.hubmapconsortium.org/entities/cdd62f7264902447922147c3098ecd6a',
#      '@type': 'Sample',
#      'donor': 'https://entity.api.hubmapconsortium.org/entities/f8d963cab6bd10e2a4b8184ea8197fc1',
#      'datasets': [{'@id': 'https://entity.api.hubmapconsortium.org/entities/8c5e705001d5cc1c40dbd963ad848486',
#        '@type': 'Dataset'},
#       {'@id': 'https://entity.api.hubmapconsortium.org/entities/ccbad4ffd323265937b842ea36ada4ad',
#        '@type': 'Dataset'}],
#      'rui_location': {'@id': 'ccf:1.5/e4853294-071d-4bef-bff3-2fd52a5c6af0',
#       'placement': {'@id': 'ccf:1.5/e4853294-071d-4bef-bff3-2fd52a5c6af0_placement',
#        '@type': 'SpatialPlacement',
#        'source': 'ccf:1.5/e4853294-071d-4bef-bff3-2fd52a5c6af0',
#        'target': 'ccf:latest/ccf.owl#VHFRightKidneyV1.1',
#        'rotation_order': 'XYZ',
#        'rotation_units': 'degree',
#        'scaling_units': 'ratio',
#        'translation_units': 'millimeter',
#        'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-42'},
#        'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '69.099'},
#        'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-71'},
#        'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '78.393'},
#        'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '-30'},
#        'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#         '@value': '1'},
#        'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#         '@value': '31.77'},
#        'creation_date': '2022-03-04'},
#       '@type': 'SpatialEntity',
#       'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0001225',
#        'http://purl.obolibrary.org/obo/UBERON_0002189',
#        'http://purl.obolibrary.org/obo/UBERON_0002015'],
#       'creator_first_name': 'Amanda',
#       'creator_last_name': 'Knoten',
#       'dimension_units': 'millimeter',
#       'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '4'},
#       'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '7'},
#       'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '2'},
#       'creation_date': '2022-03-04',
#       'creator': 'Amanda Knoten'},
#      'sample_type': 'Tissue Block',
#      'sections': None,
#      'link': 'https://portal.hubmapconsortium.org/browse/sample/cdd62f7264902447922147c3098ecd6a',
#      'description': '4 x 7 x 2 millimeter, 2 millimeter, 1 Sections',
#      'label': 'Registered 3/4/2022, Diane Salamon, TMC-UCSD'}],
#    '@type': 'Donor',
#    'age': '57',
#    'bmi': '19.6',
#    'consortium_name': 'HuBMAP',
#    'sex': 'Female',
#    'provider_name': 'TMC-UCSD',
#    'provider_uuid': '03b3d854-ed44-11e8-8bce-0e368f3075e8',
#    'link': 'https://portal.hubmapconsortium.org/browse/donor/f8d963cab6bd10e2a4b8184ea8197fc1',
#    'description': 'Entered 1/8/2020, Diane Salamon, TMC-UCSD',
#    'label': 'Female, Age 57, BMI 19.6'},
#   {'@id': 'https://entity.api.hubmapconsortium.org/entities/ff043e8a4b6d7b21620ad9f0978238d0',
#    'samples': {'@id': 'https://entity.api.hubmapconsortium.org/entities/d9e64e77d26d9fb8133d7754d1c3f6d0',
#     '@type': 'Sample',
#     'donor': 'https://entity.api.hubmapconsortium.org/entities/ff043e8a4b6d7b21620ad9f0978238d0',
#     'datasets': {'@id': 'https://entity.api.hubmapconsortium.org/entities/018a905cdbdff684760859f594d3fd77',
#      '@type': 'Dataset'},
#     'rui_location': {'@id': 'ccf:1.5/825ec2b8-1291-4633-8a63-b35c7cd709bd',
#      'placement': {'@id': 'ccf:1.5/825ec2b8-1291-4633-8a63-b35c7cd709bd_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/825ec2b8-1291-4633-8a63-b35c7cd709bd',
#       'target': 'ccf:latest/ccf.owl#VHFRightKidneyV1.1',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-41'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '51.811'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '-30'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '39.007'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '27'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '45.77'},
#       'creation_date': '2022-06-09'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0001224',
#       'http://purl.obolibrary.org/obo/UBERON_0001227',
#       'http://purl.obolibrary.org/obo/UBERON_0006517'],
#      'creator_first_name': 'Amanda',
#      'creator_last_name': 'Knoten',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '2'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '3'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '2'},
#      'creation_date': '2022-06-09',
#      'creator': 'Amanda Knoten'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://portal.hubmapconsortium.org/browse/sample/d9e64e77d26d9fb8133d7754d1c3f6d0',
#     'description': '2 x 3 x 2 millimeter, 2 millimeter, 1 Sections',
#     'label': 'Registered 6/9/2022, Amanda Knoten, TMC-UCSD'},
#    '@type': 'Donor',
#    'age': '75',
#    'bmi': '32',
#    'consortium_name': 'HuBMAP',
#    'sex': 'Female',
#    'provider_name': 'TMC-UCSD',
#    'provider_uuid': '03b3d854-ed44-11e8-8bce-0e368f3075e8',
#    'link': 'https://portal.hubmapconsortium.org/browse/donor/ff043e8a4b6d7b21620ad9f0978238d0',
#    'description': 'Entered 11/30/2021, Amanda Knoten, TMC-UCSD',
#    'label': 'Female, Age 75'},
#   {'@id': 'https://entity.api.hubmapconsortium.org/entities/ff831c86a141380f572fa9a2ba7cae52',
#    'samples': {'@id': 'https://entity.api.hubmapconsortium.org/entities/b990855403804a1b9f462bccd834a8ec',
#     '@type': 'Sample',
#     'donor': 'https://entity.api.hubmapconsortium.org/entities/ff831c86a141380f572fa9a2ba7cae52',
#     'datasets': {'@id': 'https://entity.api.hubmapconsortium.org/entities/56060793c38c82d8c312e5e05d5d189b',
#      '@type': 'Dataset'},
#     'rui_location': {'@id': 'ccf:1.5/7af72c8f-7fa1-4083-be74-613f92ef020a',
#      'placement': {'@id': 'ccf:1.5/7af72c8f-7fa1-4083-be74-613f92ef020a_placement',
#       '@type': 'SpatialPlacement',
#       'source': 'ccf:1.5/7af72c8f-7fa1-4083-be74-613f92ef020a',
#       'target': 'ccf:latest/ccf.owl#VHFUrinaryBladder',
#       'rotation_order': 'XYZ',
#       'rotation_units': 'degree',
#       'scaling_units': 'ratio',
#       'translation_units': 'millimeter',
#       'x_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '51'},
#       'x_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'x_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '28.184'},
#       'y_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '0'},
#       'y_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'y_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '21.206'},
#       'z_rotation': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '91'},
#       'z_scaling': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#        '@value': '1'},
#       'z_translation': {'@type': 'http://www.w3.org/2001/XMLSchema#double',
#        '@value': '40.35'},
#       'creation_date': '2022-06-10'},
#      '@type': 'SpatialEntity',
#      'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0006082'],
#      'creator_first_name': 'Amanda',
#      'creator_last_name': 'Knoten',
#      'dimension_units': 'millimeter',
#      'x_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '15'},
#      'y_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '17'},
#      'z_dimension': {'@type': 'http://www.w3.org/2001/XMLSchema#integer',
#       '@value': '5'},
#      'creation_date': '2022-06-10',
#      'creator': 'Amanda Knoten'},
#     'sample_type': 'Tissue Block',
#     'sections': None,
#     'link': 'https://portal.hubmapconsortium.org/browse/sample/b990855403804a1b9f462bccd834a8ec',
#     'description': '15 x 17 x 5 millimeter, 5 millimeter, 1 Sections',
#     'label': 'Registered 6/10/2022, Amanda Knoten, TMC-UCSD'},
#    '@type': 'Donor',
#    'age': '25',
#    'consortium_name': 'HuBMAP',
#    'sex': 'Female',
#    'provider_name': 'TMC-UCSD',
#    'provider_uuid': '03b3d854-ed44-11e8-8bce-0e368f3075e8',
#    'link': 'https://portal.hubmapconsortium.org/browse/donor/ff831c86a141380f572fa9a2ba7cae52',
#    'description': 'Entered 5/12/2022, Amanda Knoten, TMC-UCSD',
#    'label': 'Female, Age 25'}]}

# %%
similar_as = list(filter(lambda s: s['cell_source_type'] == "http://purl.org/ccf/AnatomicalStructure", dataset_summary[uuids[0]]['sources']))

as_labels = list(sorted(set([ s['cell_source_label'].lower() for s in similar_as if s['similarity'] > 0.66 ])))
print(uuids[0], 'anatomical structures with similar cell populations:\n', '\n '.join(as_labels))
# Out:
# 007f3dfaaa287d5c7c227651f61a9c5b anatomical structures with similar cell populations:
#  ascending colon
#  ascending part of duodenum
#  caecum
#  descending colon
#  descending part of duodenum
#  distal part of ileum
#  gastric impression of liver
#  heart left ventricle
#  horizontal part of duodenum
#  ileum
#  jejunum
#  lateral bronchopulmonary segment
#  lateral segmental bronchus
#  left apical bronchopulmonary segment
#  medial bronchopulmonary segment
#  rectum
#  right cardiac atrium
#  sigmoid colon
#  transverse colon

# %% [markdown]
# Create an HRA API session to explore the results

# %%
# Gather all RUI locations from the results
data_sources = list( json.dumps(s['rui_locations']).replace("ccf:", "http://purl.org/ccf/") for s in dataset_summary.values() )
filter_organs = list(set(organ_lookup[dataset_organ[uuid]] for uuid in uuids))
filter =  { "ontologyTerms": filter_organs }

# Get a session token for this configuration
api_response = hra_api.session_token({ "dataSources": data_sources })
token=api_response.token
print(token)
# Out:
# d227bc16e1e7ada0c5738e7a3dfdd548

# %% [markdown]
# After we get the session token, we wait to make sure the session is ready.

# %%
db_ready = False
while not db_ready:
    api_response = hra_api.db_status(token)
    print(api_response)
    if api_response.status == 'Ready':
        db_ready = True
    else:
        print('Database not ready yet! Retrying...')
        time.sleep(2)
# Out:
# status='Loading' checkback=2000 load_time=322 message='Job is queued to be run...'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=3030 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=5371 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=7463 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=9864 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=12078 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=14181 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=17278 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=19450 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=21845 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=23959 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=26056 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=28114 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=30872 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=33249 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Loading' checkback=2000 load_time=35320 message='Adding dataset'
# Database not ready yet! Retrying...
# status='Ready' checkback=3600000 load_time=36164 message='Dataset ready'

# %% [markdown]
# Show basic statistics about the gathered data

# %%
hra_api.aggregate_results(token=token, ontology_terms=filter_organs)
# Out:
# [AggregateCount(label='Consortia', count=2),
#  AggregateCount(label='Tissue Data Providers', count=4),
#  AggregateCount(label='Donors', count=36),
#  AggregateCount(label='Tissue Blocks', count=76),
#  AggregateCount(label='Extraction Sites', count=53),
#  AggregateCount(label='Tissue Sections', count=0),
#  AggregateCount(label='Tissue Datasets', count=165)]

# %% [markdown]
# # Part 3: Visualize the results

# %% [markdown]
# Imports / functions

# %%
from hra_jupyter_widgets import ( BodyUi, Eui )

# %%
def keep_node(node, selected_organs):
    organ = node.representation_of
    return (not organ) or organ in selected_organs

def filter_scene(scene, selected_organs):
    return list( json.loads(node.to_json()) for node in scene if keep_node(node, selected_organs))

# %% [markdown]
# Display tissue blocks in a 3D scene

# %%
selected_organs = [organ_lookup['skin'], organ_lookup['heart'], "http://purl.obolibrary.org/obo/UBERON_0004538", "http://purl.obolibrary.org/obo/UBERON_0004539" ]
scene = filter_scene(hra_api.scene(token=token, ontology_terms=filter_organs), selected_organs)

body_ui = BodyUi(scene=scene, height="500px")
display(body_ui)
# Out:
# BodyUi(height='500px', scene=[{'representation_of': 'http://purl.obolibrary.org/obo/UBERON_0002097', 'referenc…

# %% [markdown]
# Interact with the results in the EUI

# %%
eui = Eui(remote_api_endpoint=hra_api_endpoint_url, data_sources=data_sources, filter=filter, selected_organs=selected_organs)
display(eui)
# Out:
# Eui(data_sources=['{"@context": "https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld", "@graph"…
